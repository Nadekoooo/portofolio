# %% [markdown]
# # FIT Competition Notebook | CCC
#
# ### Notebook by CCC : Rahardi Salim, Vincent Davis Leonard Tjoeng, Christian Yudistira Hermawan
# ### University of Indonesia
#
#
# ---

# %% [markdown]
# ## FIT Competition 2024 Description

# %% [markdown]
# ### blablabla

# %% [markdown]
# ## Table of contents
#
# 1. Dataset & Utils
#
#
# *   Load datasets
# *   Utils
# *   Data Visualization
#
#
# ---
#
#
#
#
# 2. EDA (Exploratory Data Analysis)
#
#
#
# *   Understanding Data Relationships and Detecting Anomalies
# *   Correlation Matrix
#
#
#
# ---
#
#
#
# 3. Cleaning & Preprocessing
#
#
# *   Functions
#
#
#
# ---
#
#
# 4. Feature Engineering & Feature Extractions
#
#
#
# ---
#
#
#
# 5. Modeling
#
#
#
# ---
#
#
#
# 6. AutoML for further modeling
#
#
#
# ---
#
#
#
# 7. Conclusion

# %% [markdown]
# ## 1. Dataset & Utils

# %% [markdown]
# ### 1.1 Utils

# %%
# Utils
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
from tqdm import tqdm
from google.colab import drive
# drive.mount('/content/drive')

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Feature engineering
from sklearn.preprocessing import MinMaxScaler

# Feature selection
from sklearn.feature_selection import mutual_info_regression as mir

# Modelling
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error as mse
from tqdm import tqdm

# Models
import xgboost as xgb
import lightgbm as lgb
# import catboost as cb
from sklearn import linear_model

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  ### 1.2 Load & Split Datasets

# %%
train_feat = pd.read_csv("")
test_feat = pd.read_csv("")
train_label = pd.read_csv("")

X_train, X_test, y_train, y_test = train_test_split(train_feat, test_feat, test_size=0.2, stratify=y, random_state=seed_value)

# %% [markdown]
# ### 1.3 Data Visualization

# %% [markdown]
# #### 1.3.1 Display the first few rows of the dataset

# %%
train_feat.head()

# %%
test_feat.head()

# %% [markdown]
# #### 1.3.2 Check data types and missing values

# %%
train_feat.null()

# %%
test_feat.null()

# %%
train_feat.nunique()

# %%
test_feat.nunique()

# %% [markdown]
# #### 1.3.3 Overall Visualization

# %%
#pake pandasprofiling

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %% [markdown]
# ### 2.1 Understanding Data Relationships and Detecting Anomalies

# %% [markdown]
# ### 2.2 Correlation Matrix

# %% [markdown]
# #### 2.2.1 Spearman Correlation

# %% [markdown]
# #### 2.2.2 Pearson Correlation

# %% [markdown]
# ## 3. Cleaning & Prepocessing

# %% [markdown]
# ### 3.1 Functions

# %% [markdown]
# #### 3.1.1 XXXX

# %% [markdown]
# ## 4. Feature Engineering & Feature Extractions

# %% [markdown]
# ## 5. Modeling

# %% [markdown]
# ### 5.1 Choosing the best model

# %% [markdown]
# ### 5.2 Optuna for hyperparameter Tuning

# %% [markdown]
# #### 5.2.1 Objective Setting

# %% [markdown]
# #### 5.2.2 Optuna Find parameters

# %% [markdown]
# ### 5.3 Model with hyperparameter

# %% [markdown]
# ## 6. AutoML for further modeling

# %% [markdown]
# ## 7. Conclusion
